# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('./laptop_price.csv')

# %%
df.sample(7)
# Out:
#       laptop_ID  Company                            Product   TypeName
# 515         522     Asus                       VivoBook E12    Netbook  \
# 554         561       HP                        ProBook 470   Notebook
# 675         683      MSI                          GP62 7RDX     Gaming
# 292         297       HP  17-BS037cl (i3-6006U/8GB/1TB/W10)   Notebook
# 65           67     Asus                        ZenBook Pro  Ultrabook
# 1118       1133  Toshiba                  Portege X30-D-10K  Ultrabook
# 976         990   Lenovo                      ThinkPad T460   Notebook
#
#       Inches   ScreenResolution                                   Cpu   Ram
# 515     11.6           1366x768  Intel Celeron Dual Core N3350 1.1GHz   2GB  \
# 554     17.3  Full HD 1920x1080            Intel Core i7 7500U 2.7GHz   8GB
# 675     15.6  Full HD 1920x1080           Intel Core i7 7700HQ 2.8GHz  16GB
# 292     17.3           1600x900              Intel Core i3 6006U 2GHz   8GB
# ...
